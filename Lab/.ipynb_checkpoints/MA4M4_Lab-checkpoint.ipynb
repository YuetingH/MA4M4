# %% [markdown]
# # MA4M4: Lab Class

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import betterspy

# %% [markdown]
# ## 1. Preliminaries

# %% [markdown]
# ### Graph 1

# %% [markdown]
# - **Import the network data**

# %%
fh = open("out.brunson_southern-women_southern-women", "rb")
G = nx.read_edgelist(fh, comments='%',create_using=nx.Graph())   
fh.close()

# %% [markdown]
# - **Visualize the network**

# %%
nx.draw(G, pos = nx.spring_layout(G, k=5), with_labels=True) # Take times for large network
plt.axis("on");

# %% [markdown]
# - **Adjacency Matrix**

# %%
adj = nx.adjacency_matrix(G)
betterspy.show(adj)

# %% [markdown]
# ### Graph 2

# %% [markdown]
# - **Import the network data**

# %%
fh = open("out.brunson_south-africa_south-africa", "rb")
G = nx.read_edgelist(fh, comments='%',create_using=nx.Graph())   
fh.close()

# %% [markdown]
# - **Visualize the network**

# %%
nx.draw(G, pos = nx.spring_layout(G, k=5), with_labels=True) # Take times for large network
plt.axis("on");

# %% [markdown]
# - **Adjacency Matrix**

# %%
adj = nx.adjacency_matrix(G)
betterspy.show(adj)

# %% [markdown]
# ## 2. Basic structural properties of networks

# %% [markdown]
# From now on, we work on Graph 2

# %% [markdown]
# ### 2a. Focus on one of the above empirical networks. Compute the degree distribution and visualize its histogram. What is the mean and variance of the degrees?

# %% [markdown]
# - Degree Distribution

# %%
degree= np.array([b for x,b in nx.degree(G)])
pk = degree/np.sum(degree)
plt.hist(degree,density=True);

# %% [markdown]
# - Mean and Variance of the Degrees

# %%
mean_degree = np.mean(degree)
print("Mean Degree is", mean_degree)

var_degree = np.var(degree)
print("Variance of Degree is", var_degree)
# Out:
# Mean Degree is 3.6666666666666665
# Variance of Degree is 2.2222222222222223

# %% [markdown]
# ### 2b. Compute the local clustering coefficient, closeness centrality, and betweenness centrality of nodes in the network. Measure the correlation between degrees, betweenness, and closeness centrality. The correlation can either be estimated with the centrality values (Pearson) or with their associated ranking (Kendall’s tau or Spearman’s rho).

# %% [markdown]
# - Local Clustering Coefficient

# %%
cc = nx.clustering(G)
print(cc)
# Out:
# {'1': 0.5, '2': 0.3333333333333333, '3': 0.6666666666666666, '4': 1.0, '5': 0, '6': 1.0}

# %% [markdown]
# - Closeness Centrality

# %%
closeness = nx.closeness_centrality(G)
closeness = np.array(tuple(dict.values(closeness)))
print(closeness)
# Out:
# [0.83333333 0.83333333 0.71428571 0.55555556 0.5        0.625     ]

# %% [markdown]
# - Betweenness Centrality

# %%
betweenness = nx.betweenness_centrality(G)
betweenness = np.array(tuple(dict.values(betweenness)) )
print(betweenness)
# Out:
# [0.25 0.45 0.1  0.   0.   0.  ]

# %% [markdown]
# - Correlation

# %%
degree = np.array([b for x,b in nx.degree(G)])
r1 = np.corrcoef(degree, betweenness)
r2 = np.corrcoef(degree, closeness)
r3 = np.corrcoef(closeness, betweenness)

# %%
print("Between degrees and betweeness: "); print(r1)
print("Between degrees and closeness: "); print(r2)
print("Between betweenness and closeness: "); print(r3)
# Out:
# Between degrees and betweeness:
# [[1.         0.57849241]
#  [0.57849241 1.        ]]
# Between degrees and closeness:
# [[1.         0.76023819]
#  [0.76023819 1.        ]]
# Between betweenness and closeness:
# [[1.         0.87686944]
#  [0.87686944 1.        ]]

# %% [markdown]
# ### 2c. Create two visualizations for the empirical networks (i) nodes are colored based on degree and (ii) nodes are colored based on betweenness centrality.

# %% [markdown]
# - nodes are colored based on degree

# %%
nx.draw(G,pos = nx.spring_layout(G), node_color = degree, with_labels = True)

# %% [markdown]
# - nodes are colored based on betweenness centrality

# %%
nx.draw(G,pos = nx.spring_layout(G), node_color = betweenness, with_labels = True)

# %% [markdown]
# ### 2d. Find the shortest path between all pairs of nodes. What algorithm is the built-in function using? Now, compute the number of components in the network, delete the 5% of nodes with highest betweenness centrality, and recompute the number of components. Has it changed?

# %% [markdown]
# - Shortest Path
#
#     Algorithm: The algorithm to use to compute the path. Supported options: ‘dijkstra’, ‘bellman-ford’.

# %%
nx.shortest_path(G)
# Out:
# {'1': {'1': ['1'],
#   '2': ['1', '2'],
#   '3': ['1', '3'],
#   '4': ['1', '4'],
#   '6': ['1', '6'],
#   '5': ['1', '2', '5']},
#  '2': {'2': ['2'],
#   '1': ['2', '1'],
#   '3': ['2', '3'],
#   '5': ['2', '5'],
#   '6': ['2', '6'],
#   '4': ['2', '1', '4']},
#  '3': {'3': ['3'],
#   '1': ['3', '1'],
#   '2': ['3', '2'],
#   '4': ['3', '4'],
#   '6': ['3', '1', '6'],
#   '5': ['3', '2', '5']},
#  '4': {'4': ['4'],
#   '3': ['4', '3'],
#   '1': ['4', '1'],
#   '2': ['4', '3', '2'],
#   '6': ['4', '1', '6'],
#   '5': ['4', '3', '2', '5']},
#  '5': {'5': ['5'],
#   '2': ['5', '2'],
#   '1': ['5', '2', '1'],
#   '3': ['5', '2', '3'],
#   '6': ['5', '2', '6'],
#   '4': ['5', '2', '1', '4']},
#  '6': {'6': ['6'],
#   '1': ['6', '1'],
#   '2': ['6', '2'],
#   '3': ['6', '1', '3'],
#   '4': ['6', '1', '4'],
#   '5': ['6', '2', '5']}}

# %% [markdown]
# - Component

# %%
print(nx.number_connected_components(G))
# Out:
# 1

# %% [markdown]
# - Remove Point

# %%
fh = open("out.brunson_south-africa_south-africa", "rb")
G = nx.read_edgelist(fh, comments='%',create_using=nx.Graph())   
fh.close()

# %%
G.remove_node('1'); G.edges
# Out:
# EdgeView([('2', '3'), ('2', '5'), ('2', '6'), ('3', '4'), ('3', '3'), ('5', '5')])

# %%
print(nx.number_connected_components(G))
# Out:
# 1

# %% [markdown]
# The number of components is not changed.

# %% [markdown]
# ### 2e. Numerically compute the eigenvalues of the adjacency matrix, the (combinatorial) Laplacian matrix and the normalised Laplacian matrix of the empirical network. Verify the relationship between the number of components and the number of 0 eigenvalues of the Laplacian. What can be said about the range of the eigenvalues of the normalised Laplacian matrix?

# %%
fh = open("out.brunson_south-africa_south-africa", "rb")
G = nx.read_edgelist(fh, comments='%',create_using=nx.Graph())   
fh.close()

# %%
adj_arr = adj.toarray()
adj_eig = np.linalg.eig(adj_arr)
print("Eigenvalues of Adjacency: ", adj_eig[0])
print("Number: ", len(adj_eig[0]))
# Out:
# Eigenvalues of Adjacency:  [ 3.59705387 -1.56913141 -1.         -0.173973    1.43771487  0.70833568]
# Number:  6

# %%
from scipy.sparse import csgraph
L_arr = csgraph.laplacian(adj_arr, normed=True)
L_eig = np.linalg.eig(L_arr)
print("Eigenvalues of Laplacian: ", L_eig[0])
print("Number: ", len(L_eig[0]))
# Out:
# Eigenvalues of Laplacian:  [-1.11022302e-16  5.80684321e-01  8.90636121e-01  1.32096223e+00
#   1.50000000e+00  1.70771733e+00]
# Number:  6

# %% [markdown]
# The eigenvalues of the normalised Laplacian matrix theoretically should be all equal to or larger than 0. But there seems to be some numerical error here.

# %% [markdown]
# ## 3. Random graph models

# %% [markdown]
# ### 3a. Consider an unweighted and undirected empirical network G. Generate (i) an Erdös-Rényi graph with an expected total edge weight equal to the total edge weight in G and (ii) a configuration random graph with the same degree sequence as G.

# %% [markdown]
# - an Erdös-Rényi graph with an expected total edge weight equal to the total edge weight in G

# %%
N = len(adj_arr)
p = mean_degree/(N-1)

# %%
G_ER = nx.gnp_random_graph(N,p)
nx.draw(G_ER, pos = nx.spring_layout(G_ER, k=5), with_labels=True) # Take times for large network

# %% [markdown]
# - a configuration random graph with the same degree sequence as G

# %%
degree_sequence= [d for u,d in G.degree()]
G_cm = nx.configuration_model(degree_sequence)
nx.draw(G_cm, pos = nx.spring_layout(G_cm, k=5), with_labels=True) # Take times for large network
